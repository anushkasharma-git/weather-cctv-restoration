# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkasharma-git/weather-cctv-restoration/blob/main/deblurring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p "/content/drive/MyDrive/CCTV_Deblurring_Project/Datasets/Raw"

# %%
import cv2
from google.colab.patches import cv2_imshow

# Load Image
img_path = '/content/drive/MyDrive/CCTV_Deblurring_Project/raw images/img2.jpg'
img = cv2.imread(img_path)

# Resize to model size (example: 256x256)
resized = cv2.resize(img, (256, 256))

# Save resized image
save_path = '/content/drive/MyDrive/CCTV_Deblurring_Project/raw images/img2.jpg'
cv2.imwrite(save_path, resized)

# Show result
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# !mkdir -p "/content/drive/MyDrive/CCTV_Deblurring_Project/Datasets/dense_haze"

# %cd /content/drive/MyDrive/CCTV_Deblurring_Project/Datasets/dense_haze

# !wget https://data.vision.ee.ethz.ch/cvl/ntire19/dense-haze/files/Dense_Haze_NTIRE19.zip -O residest.zip
# !unzip residest.zip
# !rm residest.zip
# Out:
# /content/drive/MyDrive/CCTV_Deblurring_Project/Datasets/dense_haze
# --2025-12-01 19:06:09--  https://data.vision.ee.ethz.ch/cvl/ntire19/dense-haze/files/Dense_Haze_NTIRE19.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245267680 (234M) [application/zip]
# Saving to: ‘residest.zip’
#
# residest.zip        100%[===================>] 233.91M  14.6MB/s    in 18s
#
# 2025-12-01 19:06:28 (13.2 MB/s) - ‘residest.zip’ saved [245267680/245267680]
#
# Archive:  residest.zip
#    creating: GT/
#   inflating: GT/01_GT.png
#   inflating: GT/02_GT.png
#   inflating: GT/03_GT.png
#   inflating: GT/04_GT.png
#   inflating: GT/05_GT.png
#   inflating: GT/06_GT.png
#   inflating: GT/07_GT.png
#   inflating: GT/08_GT.png
#   inflating: GT/09_GT.png
#   inflating: GT/10_GT.png
# ...

# %%
# !ls "/content/drive/MyDrive/CCTV_Deblurring_Project/Datasets/dense_haze"
# Out:
# GT  hazy
